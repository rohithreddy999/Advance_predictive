# %% [markdown]
# <a href="https://colab.research.google.com/github/rohithreddy999/Advance_predictive/blob/main/LINEAR_REGRESSION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("Advertising.csv")
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
df.isnull().any()
# Out:
# Unnamed: 0    False
# TV            False
# Radio         False
# Newspaper     False
# Sales         False
# dtype: bool

# %%
df=df.drop(columns="Unnamed: 0")

# %%
x=df.drop(columns="Sales",axis=1)
x.head()
# Out:
#       TV  Radio  Newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3
# 3  151.5   41.3       58.5
# 4  180.8   10.8       58.4

# %%
y=df[["Sales"]]
y.head()
# Out:
#    Sales
# 0   22.1
# 1   10.4
# 2    9.3
# 3   18.5
# 4   12.9

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
fitting=model.fit(x_train,y_train)

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error
score=r2_score(y_pred,y_test)
score
# Out:
# 0.8330284237692487

# %%
mse = mean_squared_error(y_pred, y_test)
mse
# Out:
# 4.402118291449685

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
from sklearn.preprocessing import MinMaxScaler
scale=MinMaxScaler()
x_scale=scale.fit_transform(x)
y_scale=scale.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_scale,y_scale,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
model1=LinearRegression()

# %%
model1.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model1.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error
score1=r2_score(y_pred,y_test)
score1
# Out:
# 0.8330284237692487

# %%
mse1 = mean_squared_error(y_pred, y_test)
mse1
# Out:
# 0.006823296998341009
